# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Corn_Yield.csv')
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree = 2)
x_poly = pf.fit_transform(x)
poly_reg = LinearRegression()
poly_reg.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
print(x_poly)
# Out:
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 5.26000000e+00 2.76676000e+01 1.45531576e+02]
#  [1.00000000e+00 1.05300000e+01 1.10880900e+02 1.16757588e+03]
#  [1.00000000e+00 1.57900000e+01 2.49324100e+02 3.93682754e+03]
#  [1.00000000e+00 2.10500000e+01 4.43102500e+02 9.32730763e+03]
#  [1.00000000e+00 2.63200000e+01 6.92742400e+02 1.82329800e+04]
#  [1.00000000e+00 3.15800000e+01 9.97296400e+02 3.14946203e+04]
#  [1.00000000e+00 3.68400000e+01 1.35718560e+03 4.99987175e+04]
#  [1.00000000e+00 4.21100000e+01 1.77325210e+03 7.46716459e+04]
#  [1.00000000e+00 4.73700000e+01 2.24391690e+03 1.06294344e+05]
#  [1.00000000e+00 5.26300000e+01 2.76991690e+03 1.45780726e+05]
#  [1.00000000e+00 5.78900000e+01 3.35125210e+03 1.94003984e+05]
#  [1.00000000e+00 6.31600000e+01 3.98918560e+03 2.51956962e+05]
#  [1.00000000e+00 6.84200000e+01 4.68129640e+03 3.20294300e+05]
#  [1.00000000e+00 7.36800000e+01 5.42874240e+03 3.99989740e+05]
# ...

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x, y, color='blue')
plt.plot(x, lin_reg.predict(x), color='red') #prediction of linear reg
plt.title('Linear Regression for Crop Yield')
plt.xlabel('Fertilizer used')
plt.ylabel('Corn Yield')
# Out:
# Text(0, 0.5, 'Corn Yield')

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(x, y, color='blue')
plt.plot(x, poly_reg.predict(x_poly), color='red') #prediction of ploy reg of x_poly
plt.title('Polynomial Regression for Crop Yield')
plt.xlabel('Fertilizer used')
plt.ylabel('Corn Yield')
# Out:
# Text(0, 0.5, 'Corn Yield')

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]]) #2D array required
# Out:
# array([-33.19744314])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
poly_reg.predict(pf.fit_transform([[6.5]])) #pf.fit_transform is necessary here in this condition
# Out:
# array([15.23318722])
